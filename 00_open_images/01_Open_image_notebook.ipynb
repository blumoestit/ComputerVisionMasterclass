# %% [markdown]
# # Open image in a notebook

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
img = cv2.imread('/Users/magdalenablum-oeste/Google Drive/GitHubMBO/ComputerVisionMasterclass/We.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (900, 1600, 3)

# %% [markdown]
# ## OpenCV and matplotlib expect different orders of BGR / RGB
# Therefore image opened with cv2 shows strange colors in plt

# %%
plt.imshow(img);

# %%
img_RGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_RGB);
